# %%
import pandas as pd
import matplotlib as plt

# %%
file_path = "../50TH-Percentile-Rent-Estimates-Data/Merged_Data/rent20-22.csv"
DFrame = pd.read_csv(file_path)

# %%
DFrame.head()
# Out:
#    Unnamed: 0  state  county          county name state initial  studio_2020  \
# 0           0     48      59      Callahan County            TX          673
# 1           1     48     253         Jones County            TX          673
# 2           2     48     441        Taylor County            TX          673
# 3           3     72       3     Aguada Municipio            PR          386
# 4           4     72       5  Aguadilla Municipio            PR          386
#
#    studio_2021  studio_2022  bedroom_1_2020  bedroom_1_2021  ...  \
# 0        761.0        715.0             699           789.0  ...
# 1        761.0        715.0             699           789.0  ...
# 2        761.0        715.0             699           789.0  ...
# 3        401.0        407.0             397           414.0  ...
# 4        401.0        407.0             397           414.0  ...
#
#    bedroom_2_2020  bedroom_2_2021  bedroom_2_2022  bedroom_3_2020  \
# ...

# %%
pruneDF = DFrame
del pruneDF["pop2017"]
del pruneDF["Unnamed: 0"]
pruneDF.head()
# Out:
#    state  county          county name state initial  studio_2020  studio_2021  \
# 0     48      59      Callahan County            TX          673        761.0
# 1     48     253         Jones County            TX          673        761.0
# 2     48     441        Taylor County            TX          673        761.0
# 3     72       3     Aguada Municipio            PR          386        401.0
# 4     72       5  Aguadilla Municipio            PR          386        401.0
#
#    studio_2022  bedroom_1_2020  bedroom_1_2021  bedroom_1_2022  \
# 0        715.0             699           789.0           760.0
# 1        715.0             699           789.0           760.0
# 2        715.0             699           789.0           760.0
# 3        407.0             397           414.0           423.0
# 4        407.0             397           414.0           423.0
#
#    bedroom_2_2020  bedroom_2_2021  bedroom_2_2022  bedroom_3_2020  \
# ...

# %%
twenty_studio_max = pruneDF["studio_2020"].max()
twenty_studio_min = pruneDF["studio_2020"].min()
twentyone_studio_max = pruneDF["studio_2021"].max()
twentyone_studio_min = pruneDF["studio_2021"].min()
twentytwo_studio_max = pruneDF["studio_2022"].max()
twentytwo_studio_min = pruneDF["studio_2022"].min()
print(f"For Studios, the maximum rent price in 2020 is ${twenty_studio_max}, and the minimum is ${twenty_studio_min}. The maximum rent price in 2021 is ${twentyone_studio_max}, and the minimum is ${twentyone_studio_min}. Lastly, the maximum rent price in 2022 is ${twentytwo_studio_max}, and the minimum is ${twentytwo_studio_min}.")
# Out:
# For Studios, the maximum rent price in 2020 is $2288, and the minimum is $338. The maximum rent price in 2021 is $2447.0, and the minimum is $337.0. Lastly, the maximum rent price in 2022 is $2362.0, and the minimum is $362.0.

# %%
twenty_onebed_max = pruneDF["bedroom_1_2020"].max()
twenty_onebed_min = pruneDF["bedroom_1_2020"].min()
twentyone_onebed_max = pruneDF["bedroom_1_2021"].max()
twentyone_onebed_min = pruneDF["bedroom_1_2021"].min()
twentytwo_onebed_max = pruneDF["bedroom_1_2022"].max()
twentytwo_onebed_min = pruneDF["bedroom_1_2022"].min()
print(f"For one-bedrooms, the maximum rent price in 2020 is ${twenty_onebed_max}, and the minimum is ${twenty_onebed_min}. The maximum rent price in 2021 is ${twentyone_onebed_max}, and the minimum is ${twentyone_onebed_min}. Lastly, the maximum rent price in 2022 is ${twentytwo_onebed_max}, and the minimum is ${twentytwo_onebed_min}.")
# Out:
# For one-bedrooms, the maximum rent price in 2020 is $2833, and the minimum is $359. The maximum rent price in 2021 is $3044.0, and the minimum is $369.0. Lastly, the maximum rent price in 2022 is $2879.0, and the minimum is $370.0.

# %%
twenty_twobed_max = pruneDF["bedroom_2_2020"].max()
twenty_twobed_min = pruneDF["bedroom_2_2020"].min()
twentyone_twobed_max = pruneDF["bedroom_2_2021"].max()
twentyone_twobed_min = pruneDF["bedroom_2_2021"].min()
twentytwo_twobed_max = pruneDF["bedroom_2_2022"].max()
twentytwo_twobed_min = pruneDF["bedroom_2_2022"].min()
print(f"For two-bedrooms, the maximum rent price in 2020 is ${twenty_twobed_max}, and the minimum is ${twenty_twobed_min}. The maximum rent price in 2021 is ${twentyone_twobed_max}, and the minimum is ${twentyone_twobed_min}. Lastly, the maximum rent price in 2022 is ${twentytwo_twobed_max}, and the minimum is ${twentytwo_twobed_min}.")
# Out:
# For two-bedrooms, the maximum rent price in 2020 is $3477, and the minimum is $409. The maximum rent price in 2021 is $3700.0, and the minimum is $421.0. Lastly, the maximum rent price in 2022 is $3486.0, and the minimum is $422.0.

# %%
twenty_threebed_max = pruneDF["bedroom_3_2020"].max()
twenty_threebed_min = pruneDF["bedroom_3_2020"].min()
twentyone_threebed_max = pruneDF["bedroom_3_2021"].max()
twentyone_threebed_min = pruneDF["bedroom_3_2021"].min()
twentytwo_threebed_max = pruneDF["bedroom_3_2022"].max()
twentytwo_threebed_min = pruneDF["bedroom_3_2022"].min()
print(f"For three-bedrooms, the maximum rent price in 2020 is ${twenty_threebed_max}, and the minimum is ${twenty_threebed_min}. The maximum rent price in 2021 is ${twentyone_threebed_max}, and the minimum is ${twentyone_threebed_min}. Lastly, the maximum rent price in 2022 is ${twentytwo_threebed_max}, and the minimum is ${twentytwo_threebed_min}.")
# Out:
# For three-bedrooms, the maximum rent price in 2020 is $4545, and the minimum is $536. The maximum rent price in 2021 is $4756.0, and the minimum is $547.0. Lastly, the maximum rent price in 2022 is $4365.0, and the minimum is $571.0.

# %%
twenty_fourbed_max = pruneDF["bedroom_4_2020"].max()
twenty_fourbed_min = pruneDF["bedroom_4_2020"].min()
twentyone_fourbed_max = pruneDF["bedroom_4_2021"].max()
twentyone_fourbed_min = pruneDF["bedroom_4_2021"].min()
twentytwo_fourbed_max = pruneDF["bedroom_4_2022"].max()
twentytwo_fourbed_min = pruneDF["bedroom_4_2022"].min()
print(f"For three-bedrooms, the maximum rent price in 2020 is ${twenty_fourbed_max}, and the minimum is ${twenty_fourbed_min}. The maximum rent price in 2021 is ${twentyone_fourbed_max}, and the minimum is ${twentyone_fourbed_min}. Lastly, the maximum rent price in 2022 is ${twentytwo_fourbed_max}, and the minimum is ${twentytwo_fourbed_min}.")
# Out:
# For three-bedrooms, the maximum rent price in 2020 is $4849, and the minimum is $572. The maximum rent price in 2021 is $5176.0, and the minimum is $599.0. Lastly, the maximum rent price in 2022 is $4793.0, and the minimum is $574.0.

# %%
minmaxDF = pd.DataFrame({
    'Studio 2020' : [twenty_studio_max, twenty_studio_min],
    'Studio 2021' : [twentyone_studio_max, twentyone_studio_min],
    'Studio 2022' : [twentytwo_studio_max, twentytwo_studio_min],
    '1 Bedroom 2020' : [twenty_onebed_max, twenty_onebed_min],
    '1 Bedroom 2021' : [twentyone_onebed_max, twentyone_onebed_min],
    '1 Bedroom 2022' : [twentytwo_onebed_max, twentytwo_onebed_min],
    '2 Bedroom 2020' : [twenty_twobed_max, twenty_twobed_min],
    '2 Bedroom 2021' : [twentyone_twobed_max, twentyone_twobed_min],
    '2 Bedroom 2022' : [twentytwo_twobed_max, twentytwo_twobed_min],
    '3 Bedroom 2020' : [twenty_threebed_max, twenty_threebed_min],
    '3 Bedroom 2021' : [twentyone_threebed_max, twentyone_threebed_min],
    '3 Bedroom 2022' : [twentytwo_threebed_max, twentytwo_threebed_min],
    '4 Bedroom 2020' : [twenty_fourbed_max, twenty_fourbed_min],
    '4 Bedroom 2021' : [twentyone_fourbed_max, twentyone_fourbed_min],
    '4 Bedroom 2022' : [twentytwo_fourbed_max, twentytwo_fourbed_min],
})

# %%
minmaxDF
# Out:
#    Studio 2020  Studio 2021  Studio 2022  1 Bedroom 2020  1 Bedroom 2021  \
# 0         2288       2447.0       2362.0            2833          3044.0
# 1          338        337.0        362.0             359           369.0
#
#    1 Bedroom 2022  2 Bedroom 2020  2 Bedroom 2021  2 Bedroom 2022  \
# 0          2879.0            3477          3700.0          3486.0
# 1           370.0             409           421.0           422.0
#
#    3 Bedroom 2020  3 Bedroom 2021  3 Bedroom 2022  4 Bedroom 2020  \
# 0            4545          4756.0          4365.0            4849
# 1             536           547.0           571.0             572
#
#    4 Bedroom 2021  4 Bedroom 2022
# 0          5176.0          4793.0
# 1           599.0           574.0

# %%
minmaxDF.plot.bar()
# Out:
# <AxesSubplot:>
